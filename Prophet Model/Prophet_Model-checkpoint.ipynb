# %% [markdown]
# ## Introduction to Prophet Model
# * Prophet is an open source software released by Facebooks co

# %%
# pip install pystan
# pip install fbprophet

# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

import warnings
warnings.filterwarnings('ignore')

# %%
#Reading the dataset

data = pd.read_csv('/content/Customers_in_a_Shop.csv',header=None)
data.columns = ['Date','Customers']
data['Date'] = pd.to_datetime(data['Date'],format="%Y-%m")
data = data.set_index('Date')

data.shape
# Out:
# (144, 1)

# %%
# head of the data
data.head()
# Out:
#             Customers
# Date
# 1949-01-01      114.0
# 1949-02-01      120.0
# 1949-03-01      134.0
# 1949-04-01       67.0
# 1949-05-01      123.0

# %%
plt.rcParams['figure.figsize']=(17,5)
plt.plot(data,color='black')
plt.title("Number of Customers Visisting in a Ice Cream Shop since 1950")
plt.show()

# %%
# splitting the training and testing data
length_train = 115
train = data.iloc[:length_train,:]
test=data.iloc[length_train:,: ]

# %%
# checking the shape of the training data
train.shape
# Out:
# (115, 1)

# %%
from fbprophet import Prophet
# initialisaing prophet model
model = Prophet()

# %%
# fitting the model with the training set
model.fit(train.reset_index().rename(columns = {'Date':'ds','Customers':'y'}))
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# making predictions on testing data
prediction = model.predict(test.reset_index().rename(columns = {'Date':'ds'}))

# %%
prediction.head()
# Out:
#           ds       trend  ...  multiplicative_terms_upper        yhat
# 0 1958-08-01  411.944893  ...                         0.0  449.267369
# 1 1958-09-01  415.291952  ...                         0.0  428.837342
# 2 1958-10-01  418.531042  ...                         0.0  405.088372
# 3 1958-11-01  421.878101  ...                         0.0  372.290197
# 4 1958-12-01  425.117191  ...                         0.0  390.303874
#
# [5 rows x 16 columns]

# %%
# prediction plot
model.plot(prediction)

# %%
# plotting the components of the model
model.plot_components(prediction)

# %%
# cross validation
from fbprophet.diagnostics import cross_validation
df_cv = cross_validation(model, horizon = '365 days')
df_cv.head()
# Out:
# INFO:fbprophet:Making 12 forecasts with cutoffs between 1952-01-01 12:00:00 and 1957-07-01 00:00:00
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
#           ds        yhat  yhat_lower  yhat_upper      y              cutoff
# 0 1952-02-01  171.877244  157.851504  185.074170  180.0 1952-01-01 12:00:00
# 1 1952-03-01  221.270782  207.790315  234.084664  193.0 1952-01-01 12:00:00
# 2 1952-04-01  140.904896  127.736725  154.726860  181.0 1952-01-01 12:00:00
# 3 1952-05-01  208.050262  195.020567  220.683086  183.0 1952-01-01 12:00:00
# 4 1952-06-01  243.505489  230.506667  257.072959  218.0 1952-01-01 12:00:00

# %%
# performance metrics
from fbprophet.diagnostics import performance_metrics
df_p = performance_metrics(df_cv)
df_p.head()
# Out:
#            horizon          mse       rmse  ...      mape     mdape  coverage
# 0 31 days 12:00:00  2551.813190  50.515475  ...  0.148399  0.147274  0.428571
# 1 32 days 12:00:00  2585.791588  50.850679  ...  0.149262  0.133197  0.392857
# 2 59 days 12:00:00  1984.472685  44.547421  ...  0.131649  0.128015  0.392857
# 3 60 days 12:00:00  1317.056832  36.291278  ...  0.102964  0.096108  0.500000
# 4 61 days 00:00:00   633.889488  25.177162  ...  0.087943  0.084006  0.535714
#
# [5 rows x 7 columns]
