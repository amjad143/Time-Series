# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
import matplotlib.pyplot as plt
import warnings

plt.style.use('seaborn')
# plt.style.use('seaborn-colorblind') #alternative
plt.rcParams['figure.figsize'] = [8, 4.5]
plt.rcParams['figure.dpi'] = 300
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Volatility Forecasting

# %% [markdown]
# ## Explaining stock returns' volatility with ARCH models

# %% [markdown]
# 1. Import the libraries:

# %%
pip install arch
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting arch
#
#   Downloading arch-4.19-cp38-cp38-win_amd64.whl (786 kB)
# Requirement already satisfied: statsmodels>=0.10 in c:\users\asus\appdata\roaming\python\python38\site-packages (from arch) (0.12.2)
# Requirement already satisfied: numpy>=1.14 in c:\programdata\anaconda3\lib\site-packages (from arch) (1.19.2)
# Requirement already satisfied: scipy>=1.2.3 in c:\programdata\anaconda3\lib\site-packages (from arch) (1.5.2)
# Requirement already satisfied: pandas>=0.23 in c:\programdata\anaconda3\lib\site-packages (from arch) (1.1.3)
# Collecting property-cached>=1.6.4
#   Downloading property_cached-1.6.4-py2.py3-none-any.whl (7.8 kB)
# Requirement already satisfied: cython>=0.29.14 in c:\users\asus\appdata\roaming\python\python38\site-packages (from arch) (0.29.17)
# Requirement already satisfied: patsy>=0.5 in c:\programdata\anaconda3\lib\site-packages (from statsmodels>=0.10->arch) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.23->arch) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.23->arch) (2020.1)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from patsy>=0.5->statsmodels>=0.10->arch) (1.15.0)
# Installing collected packages: property-cached, arch
# Successfully installed arch-4.19 property-cached-1.6.4

# %%
import pandas as pd
import yfinance as yf
from arch import arch_model

# %% [markdown]
# 2. Specify the risky asset and the time horizon:

# %%
RISKY_ASSET = 'GOOG'
START_DATE = '2015-01-01'
END_DATE = '2020-12-31'

# %% [markdown]
# 3. Download data from Yahoo Finance:

# %%
df = yf.download(RISKY_ASSET,
                start=START_DATE,
                end=END_DATE,
                adjusted=True)

print(f'Downloaded {df.shape[0]} rows of data.')
# Out:
# [*********************100%***********************]  1 of 1 completed
# Downloaded 1511 rows of data.

# %% [markdown]
# 4. Calculate daily returns:

# %%
returns = 100 * df['Adj Close'].pct_change().dropna()
returns.name = 'asset_returns'
print(f'Average return: {round(returns.mean(), 2)}%')
returns.plot(title=f'{RISKY_ASSET} returns: {START_DATE} - {END_DATE}');

plt.tight_layout()
plt.show()
# Out:
# Average return: 0.09%

# %% [markdown]
# 5. Specify the ARCH model:

# %%
model = arch_model(returns, mean='Zero', vol='ARCH', p=1, o=0, q=0)

# %% [markdown]
# 6. Estimate the model and print the summary:

# %%
model_fitted = model.fit(disp='off')
print(model_fitted.summary())
# Out:
#                         Zero Mean - ARCH Model Results
# ==============================================================================
# Dep. Variable:          asset_returns   R-squared:                       0.000
# Mean Model:                 Zero Mean   Adj. R-squared:                  0.001
# Vol Model:                       ARCH   Log-Likelihood:               -2841.28
# Distribution:                  Normal   AIC:                           5686.56
# Method:            Maximum Likelihood   BIC:                           5697.20
#                                         No. Observations:                 1510
# Date:                Fri, Apr 16 2021   Df Residuals:                     1510
# Time:                        19:32:51   Df Model:                            0
#                             Volatility Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# omega          1.8524      0.184     10.067  7.711e-24 [  1.492,  2.213]
# alpha[1]       0.4100      0.124      3.297  9.756e-04 [  0.166,  0.654]
# ========================================================================
#
# Covariance estimator: robust

# %% [markdown]
# 7. Plot the residuals and the conditional volatility:

# %%
model_fitted.plot(annualize='D')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Explaining stock returns' volatility with GARCH models

# %% [markdown]
# 1. Specify the GARCH model:

# %%
model = arch_model(returns, mean='Zero', vol='GARCH', 
                  p=1, o=0, q=1)

# %% [markdown]
# 2. Estimate the model and print the summary:

# %%
model_fitted = model.fit(disp='off')
print(model_fitted.summary())
# Out:
#                        Zero Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:          asset_returns   R-squared:                       0.000
# Mean Model:                 Zero Mean   Adj. R-squared:                  0.001
# Vol Model:                      GARCH   Log-Likelihood:               -2793.07
# Distribution:                  Normal   AIC:                           5592.14
# Method:            Maximum Likelihood   BIC:                           5608.10
#                                         No. Observations:                 1510
# Date:                Fri, Apr 16 2021   Df Residuals:                     1510
# Time:                        19:43:57   Df Model:                            0
#                               Volatility Model
# ===========================================================================
#                  coef    std err          t      P>|t|     95.0% Conf. Int.
# ---------------------------------------------------------------------------
# omega          0.2936      0.202      1.457      0.145    [ -0.101,  0.689]
# alpha[1]       0.1749      0.102      1.717  8.596e-02 [-2.473e-02,  0.374]
# beta[1]        0.7305      0.138      5.289  1.229e-07    [  0.460,  1.001]
# ===========================================================================
#
# Covariance estimator: robust

# %% [markdown]
# 3. Plot the residuals and the conditional volatility:

# %%
model_fitted.plot(annualize='D')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Implementing CCC-GARCH model for multivariate volatility forecasting

# %% [markdown]
# 1. Import the libraries:

# %%
import pandas as pd
import yfinance as yf
from arch import arch_model
import numpy as np

# %% [markdown]
# 2. Specify the risky asset and the time horizon:

# %%
RISKY_ASSETS = ['GOOG', 'MSFT', 'AAPL']
N = len(RISKY_ASSETS)
START_DATE = '2015-01-01'
END_DATE = '2020-12-31'

# %% [markdown]
# 3. Download data from Yahoo Finance:

# %%
df = yf.download(RISKY_ASSETS,
                start=START_DATE,
                end=END_DATE,
                adjusted=True)

print(f'Downloaded {df.shape[0]} rows of data.')
# Out:
# [*********************100%***********************]  3 of 3 completed
# Downloaded 1511 rows of data.

# %% [markdown]
# 4. Calculate daily returns:

# %%
returns = 100 * df['Adj Close'].pct_change().dropna()
returns.plot(subplots=True, 
            title=f'Stock returns: {START_DATE} - {END_DATE}')

plt.tight_layout()
plt.show()

# %% [markdown]
# 5. Define lists for storing objects:

# %%
coeffs = []
cond_vol = []
std_resids = []
models = []

# %% [markdown]
# 6. Estimate the univariate GARCH models:

# %%
for asset in returns.columns:
    # specify and fit the model
    model = arch_model(returns[asset], mean='Constant', 
                      vol='GARCH', p=1, o=0, q=1).fit(update_freq=0, 
                                                     disp='off')
    # store results in the lists 
    coeffs.append(model.params)
    cond_vol.append(model.conditional_volatility)
    std_resids.append(model.resid / model.conditional_volatility)
    models.append(model)

# %% [markdown]
# 7. Store the results in DataFrames:

# %%
coeffs_df = pd.DataFrame(coeffs, index=returns.columns)
cond_vol_df = pd.DataFrame(cond_vol).transpose() \
                .set_axis(returns.columns, 
                         axis='columns', 
                         inplace=False)
std_resids_df = pd.DataFrame(std_resids).transpose() \
                .set_axis(returns.columns, 
                         axis='columns', 
                         inplace=False)

# %%
coeffs_df
# Out:
#             mu     omega  alpha[1]   beta[1]
# AAPL  0.196092  0.180925  0.145504  0.803447
# GOOG  0.117260  0.322269  0.193567  0.704221
# MSFT  0.140648  0.269206  0.231539  0.693438

# %% [markdown]
# 8. Calculate the constant conditional correlation matrix (R):

# %%
R = std_resids_df.transpose() \
                 .dot(std_resids_df) \
                 .div(len(std_resids_df))

# %% [markdown]
# 9. Calculate the 1-step ahead forecast of the conditional covariance matrix :

# %%
# define objects
diag = []
D = np.zeros((N, N))

# populate the list with conditional variances
for model in models:
    diag.append(model.forecast(horizon=1).variance.values[-1][0])
# take the square root to obtain volatility from variance
diag = np.sqrt(np.array(diag))
# fill the diagonal of D with values from diag
np.fill_diagonal(D, diag)
    
# calculate the conditional covariance matrix
H = np.matmul(np.matmul(D, R.values), D)

# %%
H
# Out:
# array([[3.47175158, 1.38404799, 1.31286278],
#        [1.38404799, 2.02897166, 1.20113091],
#        [1.31286278, 1.20113091, 1.64230829]])

# %% [markdown]
# ## Forecasting the conditional covariance matrix using DCC-GARCH (Using Python and R)

# %% [markdown]
# 1. Import the libraries:

# %%
import pandas as pd

# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %% [markdown]
# 2. Install `rmgarch` R package (run only once) and load it:

# %%
# %%R
#
# #install.packages('rmgarch', repos = "http://cran.us.r-project.org")
# library(rmgarch)

# %% [markdown]
# 3. Import the dataset into R:

# %%
# %%R
#
# read.csv("C:/Program Files/R/R-4.0.5/returns.csv")
# print(head(returns, 5))
# Out:
#         AAPL       GOOG       MSFT
# 1 -0.9564189 -0.3028802  0.6714628
# 2 -2.8173221 -2.0845673 -0.9290138
# 3  0.0102438 -2.3162783 -1.4666987
# 4  1.4032572 -0.1717973  1.2689117
# 5  3.8484848  0.3141697  2.9397590

# %% [markdown]
# 4. Define the model specification:

# %%
# %%R
#
# # define GARCH(1,1) model
# univariate_spec <- ugarchspec(mean.model = list(armaOrder = c(0,0)),
#                              variance.model = list(garchOrder = c(1,1),
#                                                   model = "sGARCH"),
#                              distribution.model = "norm")
#
# # define DCC(1,1) model
# n <- dim(returns)[2]
# dcc_spec <- dccspec(uspec = multispec(replicate(n, univariate_spec)),
#                    dccOrder = c(1,1),
#                    distribution = "mvnorm")
#
# dcc_spec
# Out:
# *------------------------------*
# *       DCC GARCH Spec         *
# *------------------------------*
# Model          :  DCC(1,1)
# Estimation     :  2-step
# Distribution   :  mvnorm
# No. Parameters :  17
# No. Series     :  3

# %% [markdown]
# 5. Estimate the model:

# %%
# %%R
# dcc_fit <- dccfit(dcc_spec, data=returns)
# dcc_fit
# Out:
# *---------------------------------*
# *          DCC GARCH Fit          *
# *---------------------------------*
#
# Distribution         :  mvnorm
# Model                :  DCC(1,1)
# No. Parameters       :  17
# [VAR GARCH DCC UncQ] : [0+12+2+3]
# No. Series           :  3
# No. Obs.             :  1005
# Log-Likelihood       :  -4889.521
# Av.Log-Likelihood    :  -4.87
#
# Optimal Parameters
# -----------------------------------
#                Estimate  Std. Error  t value Pr(>|t|)
# [AAPL].mu      0.123569    0.046497  2.65760 0.007870
# [AAPL].omega   0.225659    0.088530  2.54895 0.010805
# [AAPL].alpha1  0.128393    0.035263  3.64103 0.000272
# [AAPL].beta1   0.780760    0.052609 14.84074 0.000000
# [GOOG].mu      0.080476    0.042767  1.88174 0.059872
# [GOOG].omega   0.193072    0.161134  1.19820 0.230838
# [GOOG].alpha1  0.187833    0.126945  1.47964 0.138969
# [GOOG].beta1   0.747919    0.154264  4.84831 0.000001
# [MSFT].mu      0.121999    0.044221  2.75883 0.005801
# [MSFT].omega   0.014938    0.092794  0.16098 0.872109
# [MSFT].alpha1  0.024745    0.074276  0.33314 0.739025
# [MSFT].beta1   0.969867    0.109462  8.86033 0.000000
# [Joint]dcca1   0.034478    0.013725  2.51197 0.012006
# [Joint]dccb1   0.843667    0.038480 21.92490 0.000000
#
# Information Criteria
# ---------------------
#
# Akaike       9.7642
# Bayes        9.8473
# Shibata      9.7637
# Hannan-Quinn 9.7958
#
#
# Elapsed time : 8.389535

# %% [markdown]
# 6. Calculate the 5-step ahead forecasts:

# %%
# %%R
#
# forecasts <- dccforecast(dcc_fit, n.ahead = 5)
# forecasts
# Out:
# *---------------------------------*
# *       DCC GARCH Forecast        *
# *---------------------------------*
#
# Distribution         :  mvnorm
# Model                :  DCC(1,1)
# Horizon              :  5
# Roll Steps           :  0
# -----------------------------------
#
# 0-roll forecast:
# , , 1
#
#        [,1]   [,2]   [,3]
# [1,] 1.0000 0.6456 0.6625
# [2,] 0.6456 1.0000 0.7453
# [3,] 0.6625 0.7453 1.0000
#
# , , 2
#
#        [,1]   [,2]   [,3]
# [1,] 1.0000 0.6278 0.6453
# [2,] 0.6278 1.0000 0.7340
# [3,] 0.6453 0.7340 1.0000
#
# , , 3
#
#        [,1]   [,2]   [,3]
# [1,] 1.0000 0.6121 0.6302
# [2,] 0.6121 1.0000 0.7241
# [3,] 0.6302 0.7241 1.0000
#
# , , 4
#
#        [,1]   [,2]   [,3]
# [1,] 1.0000 0.5983 0.6169
# [2,] 0.5983 1.0000 0.7154
# [3,] 0.6169 0.7154 1.0000
#
# , , 5
#
#        [,1]   [,2]   [,3]
# [1,] 1.0000 0.5862 0.6053
# [2,] 0.5862 1.0000 0.7078
# [3,] 0.6053 0.7078 1.0000

# %% [markdown]
# 7. Access the forecasts:

# %%
# %%R
#
# # conditional covariance matrix
# forecasts@mforecast$H
# # conditional correlation matrix
# forecasts@mforecast$R
# # proxy correlation process
# forecasts@mforecast$Q
# # conditional mean forecasts
# forecasts@mforecast$mu
# Out:
# , , 1
#
#           [,1]       [,2]      [,3]
# [1,] 0.1235695 0.08047593 0.1219989
# [2,] 0.1235695 0.08047593 0.1219989
# [3,] 0.1235695 0.08047593 0.1219989
# [4,] 0.1235695 0.08047593 0.1219989
# [5,] 0.1235695 0.08047593 0.1219989
